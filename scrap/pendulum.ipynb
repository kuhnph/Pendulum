# %%
#inifinte pendulum
import sympy as sp
from sympy import cos, sin
from sympy.physics.mechanics import dynamicsymbols
import dill
dill.settings['recurse'] = True


ms = [.1, .1]
Ls = [.5, .5]
g = 9.81

thetas = [dynamicsymbols(f"theta{i}") for i in range(len(Ls))]
thetaDots = [dynamicsymbols(f"theta{i}", 1) for i in range(len(Ls))]
thetaDDots = [dynamicsymbols(f"theta{i}", 2) for i in range(len(Ls))]

for i, L in enumerate(Ls):
    theta = thetas[i]

    if i == 0:
        x = L*sin(theta)
        y = -L*cos(theta)
        pos = [x,y]
    else:
        pos.append(x+L*sin(theta))
        pos.append(y-L*cos(theta))
vel = [sp.diff(pos[i], "t") for i in range(len(pos))]

j=0
for i in range(0, len(vel)-1, 2):
    if i == 0:
        KE = ms[j]*(vel[i]**2+vel[i+1]**2)/2
        PE = ms[j]*g*pos[i+1]
    else:
        KE = KE + ms[j]*(vel[i]**2+vel[i+1]**2)/2
        PE = PE+ms[j]*g*pos[i+1]
    j+=1
L = KE-PE
LEs = [(sp.diff(sp.diff(L,thetaDots[i]), 't')-sp.diff(L,thetas[i])).simplify() for i in range(len(Ls))]
print('solving')
sol = sp.solve(LEs, thetaDDots)
print('simplifying')
thetaDDots_F = [sp.lambdify(thetas+thetaDots, sol[thetaDDots[i]].simplify()) for i in range(len(Ls))]
for i in range(len(Ls)):
    dill.dump(thetaDDots_F[i], open(f"thetaddot{i}_F", "wb"))
# Out:
# solving
# simplifying

# %%
display(sol[thetaDDots[0]].simplify())
# Out:
# (2.4525e+31*sin(theta0(t) - 2*theta1(t)) + 2.5e+30*sin(theta0(t) - theta1(t))*Derivative(theta1(t), t)**2 + 2.4525e+31*sin(theta0(t) - 2*theta2(t)) + 2.5e+30*sin(theta0(t) - theta2(t))*Derivative(theta2(t), t)**2 + 2.4525e+31*sin(theta0(t) - 2*theta3(t)) + 2.5e+30*sin(theta0(t) - theta3(t))*Derivative(theta3(t), t)**2 + 2.4525e+31*sin(theta0(t) - 2*theta4(t)) + 2.5e+30*sin(theta0(t) - theta4(t))*Derivative(theta4(t), t)**2 + 1.25e+30*sin(2*theta0(t) - 2*theta1(t))*Derivative(theta0(t), t)**2 + 1.25e+30*sin(2*theta0(t) - 2*theta2(t))*Derivative(theta0(t), t)**2 + 1.25e+30*sin(2*theta0(t) - 2*theta3(t))*Derivative(theta0(t), t)**2 + 1.25e+30*sin(2*theta0(t) - 2*theta4(t))*Derivative(theta0(t), t)**2 + 1.4715e+32*sin(theta0(t)) + 346944695195361.0*sin(2.0*theta0(t))*Derivative(theta0(t), t)**2 + 281474976710656.0*sin(2*theta0(t))*Derivative(theta0(t), t)**2)/(2.5e+30*cos(theta0(t) - theta1(t))**2 + 2.5e+30*cos(theta0(t) - theta2(t))**2 + 2.5e+30*cos(theta0(t) - theta3(t))**2 + 2.5e+30*cos(theta0(t) - theta4(t))**2 - 1.25e+31)

# %%
#inifinte pendulum with mass/length inputs
import sympy as sp
from sympy import cos, sin
from sympy.physics.mechanics import dynamicsymbols
import dill
import time
dill.settings['recurse'] = True

links = 5
g = 9.81

ms = [sp.symbols(f"m{i}") for i in range(links)]
Ls = [sp.symbols(f"L{i}") for i in range(links)]
thetas = [dynamicsymbols(f"theta{i}") for i in range(links)]
thetaDots = [dynamicsymbols(f"theta{i}", 1) for i in range(links)]
thetaDDots = [dynamicsymbols(f"theta{i}", 2) for i in range(links)]
thetas_2 = [sp.symbols(f"theta_{i}") for i in range(links)]
thetaDots_2 = [sp.symbols(f"thetaDot_{i}") for i in range(links)]
thetaDDots_2 = [sp.symbols(f"thetaDDot_{i}") for i in range(links)]

for i, L in enumerate(Ls):
    theta = thetas[i]

    if i == 0:
        x = L*sin(theta)
        y = -L*cos(theta)
        pos = [x,y]
    else:
        pos.append(x+L*sin(theta))
        pos.append(y-L*cos(theta))
vel = [sp.diff(pos[i], "t") for i in range(len(pos))]

j=0
for i in range(0, len(vel)-1, 2):
    if i == 0:
        KE = ms[j]*(vel[i]**2+vel[i+1]**2)/2
        PE = ms[j]*g*pos[i+1]
    else:
        KE = KE + ms[j]*(vel[i]**2+vel[i+1]**2)/2
        PE = PE+ms[j]*g*pos[i+1]
    j+=1
L = KE-PE
LEs = [(sp.diff(sp.diff(L,thetaDots[i]), 't')-sp.diff(L,thetas[i])).simplify() for i in range(len(Ls))]

for i in range(len(LEs)):
    for ii in range(len(thetaDDots_2)):
        LEs[i] = LEs[i].subs([(thetaDDots[ii], thetaDDots_2[ii]), (thetaDots[ii], thetaDots_2[ii]),  (thetas[ii], thetas_2[ii])])

print('solving')
T_start = time.time()
sol = sp.solve(LEs, thetaDDots_2)
print(f"solve time = {format(time.time()-T_start, '2f')}")

print('simplifying')
for i in range(len(Ls)):
    sol[thetaDDots_2[i]] = sol[thetaDDots_2[i]].simplify()

print("lambdifying")
thetaDDots_F = [sp.lambdify(thetas_2+thetaDots_2+ms+Ls, sol[thetaDDots_2[i]]) for i in range(len(Ls))]
for i in range(len(Ls)):
    dill.dump(thetaDDots_F[i], open(f"thetaddot{i}_F", "wb"))
# Out:
# solving
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\core.py in __cmp__(cls, other)
#      84         try:
# ---> 85             i1 = ordering_of_classes.index(n1)
#      86         except ValueError:
#
# ValueError: 'cos' is not in list
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12280/2892879198.py in <module>
#      49 print('solving')
#      50 T_start = time.time()
# ---> 51 sol = sp.solve(LEs, thetaDDots_2)
#      52 print(f"solve time = {format(time.time()-T_start, '2f')}")
#      53
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\solvers.py in solve(f, *symbols, **flags)
#    1106         solution = _solve(f[0], *symbols, **flags)
#    1107     else:
# -> 1108         solution = _solve_system(f, symbols, **flags)
#    1109
#    1110     #
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\solvers.py in _solve_system(exprs, symbols, **flags)
#    1823                 result = minsolve_linear_system(matrix, *symbols, **flags)
#    1824             else:
# -> 1825                 result = solve_linear_system(matrix, *symbols, **flags)
#    1826             if failed:
#    1827                 if result:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\solvers\solvers.py in solve_linear_system(system, *symbols, **flags)
#    2317     eqs = list(system * Matrix(symbols + (-1,)))
#    2318     eqs, ring = sympy_eqs_to_ring(eqs, symbols)
# -> 2319     sol = solve_lin_sys(eqs, ring, _raw=False)
#    2320     if sol is not None:
#    2321         sol = {sym:val for sym, val in sol.items() if sym != val}
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\solvers.py in solve_lin_sys(eqs, ring, _raw)
#     277         eqs_coeffs.append(eq_coeffs)
#     278
# --> 279     result = _solve_lin_sys(eqs_coeffs, eqs_rhs, ring)
#     280
#     281     if result is not None and as_expr:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\solvers.py in _solve_lin_sys(eqs_coeffs, eqs_rhs, ring)
#     355     sol = {}
#     356     for subsystem in subsystems:
# --> 357         subsol = _solve_lin_sys_component(subsystem[0], subsystem[1], ring)
#     358         if subsol is None:
#     359             return None
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\solvers.py in _solve_lin_sys_component(eqs_coeffs, eqs_rhs, ring)
#     403
#     404     # solve by row-reduction
# --> 405     echelon, pivots = matrix.rref()
#     406
#     407     # construct the returnable form of the solutions
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\matrices\domainmatrix.py in rref(self)
#    1271         if not self.domain.is_Field:
#    1272             raise DMNotAField('Not a field')
# -> 1273         rref_ddm, pivots = self.rep.rref()
#    1274         return self.from_rep(rref_ddm), tuple(pivots)
#    1275
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\matrices\ddm.py in rref(a)
#     385         K = a.domain
#     386         partial_pivot = K.is_RealField or K.is_ComplexField
# --> 387         pivots = ddm_irref(b, _partial_pivot=partial_pivot)
#     388         return b, pivots
#     389
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\matrices\dense.py in ddm_irref(a, _partial_pivot)
#     141             ak[j] -= akj # ak[j] = zero
#     142             for l in range(j+1, n):
# --> 143                 ak[l] -= akj * ai[l]
#     144
#     145         # next row
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\domains\expressiondomain.py in __sub__(f, g)
#      87                 return -g
#      88             else:
# ---> 89                 return f.simplify(f.ex - g.ex)
#      90
#      91         def __rsub__(f, g):
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\domains\expressiondomain.py in simplify(f, ex)
#      48
#      49         def simplify(f, ex):
# ---> 50             return f.__class__(ex.cancel().expand(**eflags))
#      51
#      52         def __abs__(f):
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\expr.py in cancel(self, *gens, **args)
#    3731         """See the cancel function in sympy.polys"""
#    3732         from sympy.polys.polytools import cancel
# -> 3733         return cancel(self, *gens, **args)
#    3734
#    3735     def invert(self, g, *gens, **args):
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\polys\polytools.py in cancel(f, _signsimp, *gens, **args)
#    6750         if f.is_Number or isinstance(f, Relational) or not isinstance(f, Expr):
#    6751             return f
# -> 6752         f = factor_terms(f, radical=True)
#    6753         p, q = f.as_numer_denom()
#    6754
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\exprtools.py in factor_terms(expr, radical, clear, fraction, sign)
#    1275         return rv
#    1276     expr = sympify(expr)
# -> 1277     return do(expr)
#    1278
#    1279
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\exprtools.py in do(expr)
#    1265             # rebuild p not worrying about the order which gcd_terms will fix
#    1266             p = Add._from_args(list_args)
# -> 1267             p = gcd_terms(p,
#    1268                 isprimitive=True,
#    1269                 clear=clear,
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\exprtools.py in gcd_terms(terms, isprimitive, clear, fraction)
#    1076             terms = sympify(terms)
#    1077         terms, reps = mask(terms)
# -> 1078         cont, numer, denom = _gcd_terms(terms, isprimitive, fraction)
#    1079         numer = numer.xreplace(reps)
#    1080         coeff, factors = cont.as_coeff_Mul()
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\exprtools.py in _gcd_terms(terms, isprimitive, fraction)
#     974                 numers.append(term.coeff*numer.as_expr())
#     975         else:
# --> 976             numers = [t.as_expr() for t in terms]
#     977             denom = Term(S.One).numer
#     978
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\exprtools.py in <listcomp>(.0)
#     974                 numers.append(term.coeff*numer.as_expr())
#     975         else:
# --> 976             numers = [t.as_expr() for t in terms]
#     977             denom = Term(S.One).numer
#     978
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\exprtools.py in as_expr(self)
#     861
#     862     def as_expr(self):  # Term
# --> 863         return self.coeff*(self.numer.as_expr()/self.denom.as_expr())
#     864
#     865     def mul(self, other):  # Term
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\numbers.py in __mul__(self, other)
#    2208             elif isinstance(other, Rational):
#    2209                 return Rational(self.p*other.p, other.q, igcd(self.p, other.q))
# -> 2210             return Rational.__mul__(self, other)
#    2211         return Rational.__mul__(self, other)
#    2212
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\decorators.py in __sympifyit_wrapper(a, b)
#      63                 if not hasattr(b, '_op_priority'):
#      64                     b = sympify(b, strict=True)
# ---> 65                 return func(a, b)
#      66             except SympifyError:
#      67                 return retval
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\numbers.py in __mul__(self, other)
#    1744                 return other*self
#    1745             else:
# -> 1746                 return Number.__mul__(self, other)
#    1747         return Number.__mul__(self, other)
#    1748     __rmul__ = __mul__
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\decorators.py in __sympifyit_wrapper(a, b)
#      63                 if not hasattr(b, '_op_priority'):
#      64                     b = sympify(b, strict=True)
# ---> 65                 return func(a, b)
#      66             except SympifyError:
#      67                 return retval
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\numbers.py in __mul__(self, other)
#     759         elif isinstance(other, Tuple):
#     760             return NotImplemented
# --> 761         return AtomicExpr.__mul__(self, other)
#     762
#     763     @_sympifyit('other', NotImplemented)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\decorators.py in _func(self, other)
#     234             if not isinstance(other, expectedcls):
#     235                 return retval
# --> 236             return func(self, other)
#     237
#     238         return _func
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\decorators.py in binary_op_wrapper(self, other)
#     104                     if f is not None:
#     105                         return f(self)
# --> 106             return func(self, other)
#     107         return binary_op_wrapper
#     108     return priority_decorator
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\expr.py in __mul__(self, other)
#     210     @call_highest_priority('__rmul__')
#     211     def __mul__(self, other):
# --> 212         return Mul(self, other)
#     213
#     214     @sympify_return([('other', 'Expr')], NotImplemented)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      68         def wrapper(*args, **kwargs):
#      69             try:
# ---> 70                 retval = cfunc(*args, **kwargs)
#      71             except TypeError as e:
#      72                 if not e.args or not e.args[0].startswith('unhashable type:'):
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\operations.py in __new__(cls, evaluate, _sympify, *args)
#      96             return args[0]
#      97
# ---> 98         c_part, nc_part, order_symbols = cls.flatten(args)
#      99         is_commutative = not nc_part
#     100         obj = cls._from_args(c_part + nc_part, is_commutative)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\mul.py in flatten(cls, seq)
#     702
#     703         # order commutative part canonically
# --> 704         _mulsort(c_part)
#     705
#     706         # current code expects coeff to be always in slot-0
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\mul.py in _mulsort(args)
#      33 def _mulsort(args):
#      34     # in-place sorting of args
# ---> 35     args.sort(key=_args_sortkey)
#      36
#      37
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\basic.py in compare(self, other)
#     223         n1 = self.__class__
#     224         n2 = other.__class__
# --> 225         c = (n1 > n2) - (n1 < n2)
#     226         if c:
#     227             return c
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\core.py in __lt__(cls, other)
#      95
#      96     def __lt__(cls, other):
# ---> 97         if cls.__cmp__(other) == -1:
#      98             return True
#      99         return False
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sympy\core\core.py in __cmp__(cls, other)
#      84         try:
#      85             i1 = ordering_of_classes.index(n1)
# ---> 86         except ValueError:
#      87             i1 = UNKNOWN
#      88         try:
#
# KeyboardInterrupt:

# %%
for i in range(links):
    #LEs[i] = LEs[i].factor(thetaDDots_2[1])
    display(LEs[i])
# Out:
# L0*(1.0*L0*m0*thetaDDot_0 + 1.0*L0*m1*thetaDDot_0 + 1.0*L0*m2*thetaDDot_0 + 1.0*L0*m3*thetaDDot_0 + 1.0*L0*m4*thetaDDot_0 + 1.0*L1*m1*thetaDDot_1*cos(theta_0 - theta_1) + 1.0*L1*m1*thetaDot_1**2*sin(theta_0 - theta_1) + 1.0*L2*m2*thetaDDot_2*cos(theta_0 - theta_2) + 1.0*L2*m2*thetaDot_2**2*sin(theta_0 - theta_2) + 1.0*L3*m3*thetaDDot_3*cos(theta_0 - theta_3) + 1.0*L3*m3*thetaDot_3**2*sin(theta_0 - theta_3) + 1.0*L4*m4*thetaDDot_4*cos(theta_0 - theta_4) + 1.0*L4*m4*thetaDot_4**2*sin(theta_0 - theta_4) + 9.81*m0*sin(theta_0) + 9.81*m1*sin(theta_0) + 9.81*m2*sin(theta_0) + 9.81*m3*sin(theta_0) + 9.81*m4*sin(theta_0))
# L1*m1*(1.0*L0*thetaDDot_0*cos(theta_0 - theta_1) - 1.0*L0*thetaDot_0**2*sin(theta_0 - theta_1) + 1.0*L1*thetaDDot_1 + 9.81*sin(theta_1))
# L2*m2*(1.0*L0*thetaDDot_0*cos(theta_0 - theta_2) - 1.0*L0*thetaDot_0**2*sin(theta_0 - theta_2) + 1.0*L2*thetaDDot_2 + 9.81*sin(theta_2))
# L3*m3*(1.0*L0*thetaDDot_0*cos(theta_0 - theta_3) - 1.0*L0*thetaDot_0**2*sin(theta_0 - theta_3) + 1.0*L3*thetaDDot_3 + 9.81*sin(theta_3))
# L4*m4*(1.0*L0*thetaDDot_0*cos(theta_0 - theta_4) - 1.0*L0*thetaDot_0**2*sin(theta_0 - theta_4) + 1.0*L4*thetaDDot_4 + 9.81*sin(theta_4))

# %%
#triple pendulum
import matplotlib.pyplot as plt
import sympy as sp
from math import cos, sin, pi
from sympy import cos, sin
from sympy.physics.mechanics import dynamicsymbols
import numpy as np

L1, L2, L3, m1, m2, m3, g = sp.symbols("L1, L2, L3, m1, m2, m3, g")
L1, L2, L3, m1, m2, m3, g, mu = 1.2, 1, .5, 1, 1, 1, 9.81, 0.1
theta1, theta2, theta3 = dynamicsymbols("theta1, theta2, theta3")
thetadot1, thetadot2, thetadot3 = dynamicsymbols("theta1, theta2, theta3", 1)
thetaddot1, thetaddot2, thetaddot3 = dynamicsymbols("theta1, theta2, theta3", 2)


x1 = L1*sin(theta1)
y1 = -L1*cos(theta1)
x2 = x1+L2*sin(theta2)
y2 = y1-L2*cos(theta2)
x3 = x2+L3*sin(theta3)
y3 = y2-L3*cos(theta3)
pos = [x1,y1,x2,y2,x3,y3]

vel = [sp.diff(pos[i], "t") for i in range(len(pos))]
xdot1, ydot1, xdot2, ydot2, xdot3, ydot3 = vel

KE = m1*(xdot1**2+ydot1**2)/2 + m2*(xdot2**2+ydot2**2)/2 + m3*(xdot3**2+ydot3**2)/2
PE = m1*g*y1+m2*g*y2+m3*g*y3
L = KE-PE
LE1 = sp.diff(sp.diff(L,thetadot1), 't')-sp.diff(L,theta1) #- mu*thetadot1
LE2 = sp.diff(sp.diff(L,thetadot2), 't')-sp.diff(L,theta2)# - 6*np.pi*mu*.1*thetadot2
LE3 = sp.diff(sp.diff(L,thetadot3), 't')-sp.diff(L,theta3)
sol = sp.solve((LE1,LE2,LE3), (thetaddot1, thetaddot2, thetaddot3), dict=False)
var = [theta1, theta2, theta3, thetadot1, thetadot2, thetadot3]
thetaddot1_F, thetaddot2_F, thetaddot3_F = [sp.lambdify(var, sol[thetaddot1].simplify()), sp.lambdify(var, sol[thetaddot2].simplify()), sp.lambdify(var, sol[thetaddot3].simplify())]

import dill
dill.settings['recurse'] = True
dill.dump(thetaddot1_F, open("thetaddot1_F", "wb"))
dill.dump(thetaddot2_F, open("thetaddot2_F", "wb"))
dill.dump(thetaddot3_F, open("thetaddot3_F", "wb"))

# %%
#Double pendulum

import matplotlib.pyplot as plt
import sympy as sp
from math import cos, sin, pi
from sympy import cos, sin
from sympy.physics.mechanics import dynamicsymbols
import numpy as np

L1, L2, m1, m2, g = sp.symbols("L1, L2, m1, m2, g")
L1, L2, m1, m2, g, mu = 1, 1, 1, 1, 9.81, 0.1
theta1, theta2 = dynamicsymbols("theta1, theta2")
thetadot1, thetadot2 = dynamicsymbols("theta1, theta2", 1)
thetaddot1, thetaddot2 = dynamicsymbols("theta1, theta2", 2)


x1 = L1*sin(theta1)
y1 = -L1*cos(theta1)
x2 = x1+L2*sin(theta2)
y2 = y1-L2*cos(theta2)
pos = [x1,y1,x2,y2]

vel = [sp.diff(pos[i], "t") for i in range(len(pos))]
xdot1, ydot1, xdot2, ydot2 = vel

KE = m1*(xdot1**2+ydot1**2)/2+m2*(xdot2**2+ydot2**2)/2
PE = m1*g*y1+m2*g*y2
L = KE-PE
LE1 = sp.diff(sp.diff(L,thetadot1), 't')-sp.diff(L,theta1) #- mu*thetadot1
LE2 = sp.diff(sp.diff(L,thetadot2), 't')-sp.diff(L,theta2)# - 6*np.pi*mu*.1*thetadot2
sol = sp.solve((LE1,LE2), (thetaddot1, thetaddot2), dict=False)
thetaddot1_F, thetaddot2_F = [sp.lambdify([theta1, theta2, thetadot1,thetadot2], sol[thetaddot1].simplify()), sp.lambdify((theta1, theta2, thetadot1,thetadot2), sol[thetaddot2].simplify())]

import dill
dill.settings['recurse'] = True
dill.dump(thetaddot1_F, open("thetaddot1_F", "wb"))
dill.dump(thetaddot2_F, open("thetaddot2_F", "wb"))

# %%
class animation():
    def __init__(self):
            self.fig, self.ax = plt.subplots()
            self.ax.set_xlim(-3,3)
            self.ax.set_ylim(-3,3)
            self.init = False
            self.line1 = 1
            self.line2 = 1
            self.line3 = 1
    def animate(self, state):
        theta1 = state[0][0]
        theta2 = state[1][0]
        theta3 = state[2][0]

        x1 = L1*np.sin(theta1)
        y1 = L1*np.cos(theta1)
        x2 = x1+L2*np.sin(theta2)
        y2 = y1+L2*np.cos(theta2)
        x3 = x2+L3*np.sin(theta3)
        y3 = y2+L3*np.cos(theta3)

        if not self.init:
            self.ax.set_xlim(-3,3)
            self.ax.set_ylim(-3,3)
            self.line1, = self.ax.plot((0,x1), (0,y1))
            self.line2, = self.ax.plot((x1,x2),(y1,y2))
            self.line3, = self.ax.plot((x2,x3),(y2,y3))
            self.init = True
        else:
            self.line1.set_data((0,x1), (0,y1))
            self.line2.set_data((x1,x2),(y1,y2))
            self.line3.set_data((x2,x3),(y2,y3))
            plt.pause(0.01)

# %%
def f(state, force):
    theta1 = state[0][0]
    theta2 = state[1][0]
    theta3 = state[2][0]
    thetadot1 = state[3][0]
    thetadot2 = state[4][0]
    thetadot3 = state[5][0]
    thetaddot1 = thetaddot1_F(theta1, theta2, theta3, thetadot1, thetadot2, thetadot3)
    thetaddot2 = thetaddot2_F(theta1, theta2, theta3, thetadot1, thetadot2, thetadot3)
    thetaddot3 = thetaddot3_F(theta1, theta2, theta3, thetadot1, thetadot2, thetadot3)
    xdot = np.array([[thetadot1], [thetadot2], [thetadot3], [thetaddot1], [thetaddot2], [thetaddot3]])
    #print(xdot)
    return xdot

def rk4_step(state, force, Ts):
    # Integrate ODE using Runge-Kutta RK4 algorithm
    F1 = f(state, force)
    F2 = f(state + Ts / 2 * F1, force)
    F3 = f(state + Ts / 2 * F2, force)
    F4 = f(state + Ts * F3, force)
    print(state)
    print(F1)
    state += Ts / 6 * (F1 + 2 * F2 + 2 * F3 + F4)
    return state

def update():
    #ani = animation()
    Ts = .1
    state = np.array([[181*3.14/180],[0], [0],[0],[0],[0]]).astype("float64")
    for i in range(10*20):
        state = rk4_step(state,0,Ts)
        #ani.animate(state)
update()
# Out:
# [[3.15744444]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# [[ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.46626436]
#  [ 0.46620578]
#  [-0.        ]]
# [[3.15979482e+00]
#  [2.31195037e-03]
#  [3.80828182e-05]
#  [4.73883191e-02]
#  [4.58573188e-02]
#  [1.52326302e-03]]
# [[0.04738832]
#  [0.04585732]
#  [0.00152326]
#  [0.49005182]
#  [0.44498569]
#  [0.04457684]]
# [[3.16708993e+00]
#  [9.04653636e-03]
#  [5.90804733e-04]
#  [9.99025836e-02]
#  [8.81238989e-02]
#  [1.15295391e-02]]
# [[0.09990258]
#  [0.0881239 ]
#  [0.01152954]
#  [0.57243348]
#  [0.40060628]
#  [0.16568529]]
# [[3.18018081e+00]
#  [1.98050955e-02]
#  [2.84098197e-03]
#  [1.64851133e-01]
#  [1.26865488e-01]
#  [3.61936612e-02]]
# [[0.16485113]
#  [0.12686549]
#  [0.03619366]
#  [0.74586224]
#  [0.38504255]
#  [0.33183036]]
# [[3.20084585]
#  [0.03449415]
#  [0.00841701]
#  [0.2538107 ]
#  [0.16841825]
#  [0.0782059 ]]
# [[ 5.65403536]
#  [-0.35544406]
#  [-1.17191449]
#  [-0.6121105 ]
#  [-3.70874225]
#  [ 6.70310563]]
# [[ -0.6121105 ]
#  [ -3.70874225]
#  [  6.70310563]
#  [ 17.74291027]
#  [-41.19110238]
#  [ 32.27155302]]
# [[ 5.660601  ]
#  [-0.88424377]
#  [-0.35326961]
#  [ 0.11111566]
#  [-5.08857486]
#  [ 8.42529268]]
# [[  0.11111566]
#  [ -5.08857486]
#  [  8.42529268]
#  [-18.17440655]
#  [ 63.28611015]
#  [-46.77440696]]
# [[ 5.62704992]
#  [-1.15595327]
#  [ 0.33294046]
#  [-0.42527797]
#  [-1.07148274]
#  [ 6.00796402]]
# [[-0.42527797]
#  [-1.07148274]
#  [ 6.00796402]
#  [ 2.23080141]
#  [25.41332343]
#  [-7.80630959]]
# [[ 5.60466434]
#  [-1.15179799]
#  [ 0.91255449]
#  [ 0.04315359]
#  [ 1.02733356]
#  [ 5.71597837]]
# [[ 0.04315359]
#  [ 1.02733356]
#  [ 5.71597837]
#  [ 6.10922016]
#  [17.88915532]
#  [-0.09264451]]
# [[ 5.63937774]
#  [-0.96743021]
#  [ 1.48387186]
#  [ 0.63410404]
#  [ 2.58023982]
#  [ 5.68592729]]
# [[ 0.63410404]
#  [ 2.58023982]
#  [ 5.68592729]
#  [ 5.09181784]
#  [13.05644296]
#  [-1.5950647 ]]
# [[ 5.72414698]
#  [-0.65482603]
#  [ 2.03575631]
#  [ 1.03783754]
#  [ 3.54404497]
#  [ 5.2645696 ]]
# [[ 1.03783754]
#  [ 3.54404497]
#  [ 5.2645696 ]
#  [ 3.7087014 ]
#  [ 5.36165163]
#  [-6.80983943]]
# [[ 5.85217329]
#  [-0.29276195]
#  [ 2.52364769]
#  [ 1.5810717 ]
#  [ 3.52186259]
#  [ 4.4750968 ]]
# [[ 1.5810717 ]
#  [ 3.52186259]
#  [ 4.4750968 ]
#  [ 7.5360642 ]
#  [-5.55422257]
#  [-7.96917499]]
# [[6.05201196]
#  [0.01947541]
#  [2.93473313]
#  [2.42796578]
#  [2.63788265]
#  [3.78682382]]
# [[  2.42796578]
#  [  2.63788265]
#  [  3.78682382]
#  [  8.56061181]
#  [-11.12028301]
#  [ -5.7116396 ]]
# [[6.3334172 ]
#  [0.22646604]
#  [3.28934698]
#  [3.13325266]
#  [1.53894597]
#  [3.36491187]]
# [[ 3.13325266]
#  [ 1.53894597]
#  [ 3.36491187]
#  [ 4.77394952]
#  [-9.35606985]
#  [-2.36197167]]
# [[6.65623639]
#  [0.3516947 ]
#  [3.62414679]
#  [3.17784009]
#  [1.15040168]
#  [3.43244818]]
# [[ 3.17784009]
#  [ 1.15040168]
#  [ 3.43244818]
#  [-4.19262625]
#  [ 2.12903144]
#  [ 3.77189222]]
# [[6.94214549]
#  [0.48834704]
#  [3.99167268]
#  [2.47120595]
#  [1.61858531]
#  [3.9449178 ]]
# [[ 2.47120595]
#  [ 1.61858531]
#  [ 3.9449178 ]
#  [-8.5913407 ]
#  [ 4.66662775]
#  [ 5.38748654]]
# [[7.14571995]
#  [0.66476257]
#  [4.41029383]
#  [1.60022354]
#  [1.81142759]
#  [4.39300614]]
# [[ 1.60022354]
#  [ 1.81142759]
#  [ 4.39300614]
#  [-8.60364334]
#  [-1.22065934]
#  [ 3.33246701]]
# [[7.26333704]
#  [0.82947073]
#  [4.86206652]
#  [0.7558408 ]
#  [1.39116288]
#  [4.60646112]]
# [[ 0.7558408 ]
#  [ 1.39116288]
#  [ 4.60646112]
#  [-8.37215036]
#  [-6.7587855 ]
#  [ 1.16124343]]
# [[ 7.29686725]
#  [ 0.92910339]
#  [ 5.32805688]
#  [-0.0875635 ]
#  [ 0.55331588]
#  [ 4.72805482]]
# [[-0.0875635 ]
#  [ 0.55331588]
#  [ 4.72805482]
#  [-8.50580524]
#  [-9.70413284]
#  [ 2.01826317]]
# [[ 7.24563135]
#  [ 0.93113265]
#  [ 5.81918183]
#  [-0.93456662]
#  [-0.57795299]
#  [ 5.21456357]]
# [[ -0.93456662]
#  [ -0.57795299]
#  [  5.21456357]
#  [ -8.34180016]
#  [-13.6939293 ]
#  [  9.17657017]]
# [[ 7.11115674]
#  [ 0.78806439]
#  [ 6.41504372]
#  [-1.77570063]
#  [-2.47559031]
#  [ 7.08429251]]
# [[ -1.77570063]
#  [ -2.47559031]
#  [  7.08429251]
#  [ -9.30201905]
#  [-25.42376844]
#  [ 31.7526264 ]]
# [[ 6.86061664]
#  [ 0.50400999]
#  [ 7.21857166]
#  [-3.26065146]
#  [-2.20277146]
#  [ 7.8736713 ]]
# [[ -3.26065146]
#  [ -2.20277146]
#  [  7.8736713 ]
#  [-11.76631651]
#  [ 37.33565858]
#  [-36.54401614]]
# [[ 6.50901533]
#  [ 0.41951316]
#  [ 7.83340862]
#  [-3.53490179]
#  [-0.00846197]
#  [ 4.65524984]]
# [[-3.53490179e+00]
#  [-8.46197422e-03]
#  [ 4.65524984e+00]
#  [ 3.14464470e+00]
#  [ 5.66436370e+00]
#  [-2.51062558e+01]]
# [[ 6.18207549]
#  [ 0.40950497]
#  [ 8.19582234]
#  [-2.93611092]
#  [-0.44814468]
#  [ 2.78602491]]
# [[ -2.93611092]
#  [ -0.44814468]
#  [  2.78602491]
#  [  7.51109158]
#  [-10.34985813]
#  [-13.31243882]]
# [[ 5.92876468]
#  [ 0.30690494]
#  [ 8.41745879]
#  [-2.09947527]
#  [-1.64619391]
#  [ 1.71117837]]
# [[ -2.09947527]
#  [ -1.64619391]
#  [  1.71117837]
#  [  9.37614267]
#  [-12.84743772]
#  [ -9.40487903]]
# [[ 5.77074664]
#  [ 0.07564461]
#  [ 8.53983003]
#  [-1.00144788]
#  [-3.0214132 ]
#  [ 0.69110635]]
# [[ -1.00144788]
#  [ -3.0214132 ]
#  [  0.69110635]
#  [ 13.02774787]
#  [-15.41946273]
#  [-12.13985841]]
# [[ 5.74449454]
#  [-0.31640356]
#  [ 8.53219871]
#  [ 0.5088586 ]
#  [-4.93051691]
#  [-1.07047205]]
# [[  0.5088586 ]
#  [ -4.93051691]
#  [ -1.07047205]
#  [ 15.24750155]
#  [-22.14898802]
#  [-25.24374366]]
# [[ 5.81610879]
#  [-0.85895474]
#  [ 8.29818977]
#  [ 0.50620271]
#  [-5.3426417 ]
#  [-3.38223003]]
# [[  0.50620271]
#  [ -5.3426417 ]
#  [ -3.38223003]
#  [-13.17454957]
#  [ 15.34045409]
#  [-12.18077841]]
# [[ 5.81202565]
#  [-1.31540335]
#  [ 7.92359086]
#  [-0.44066175]
#  [-3.82687736]
#  [-3.93941458]]
# [[-0.44066175]
#  [-3.82687736]
#  [-3.93941458]
#  [-4.54827476]
#  [12.99859608]
#  [-2.22441177]]
# [[ 5.75923752]
#  [-1.63873529]
#  [ 7.52171611]
#  [-0.49144232]
#  [-2.67894437]
#  [-4.07027591]]
# [[-0.49144232]
#  [-2.67894437]
#  [-4.07027591]
#  [ 2.87966758]
#  [10.61539011]
#  [-0.59022196]]
# [[ 5.73243459]
#  [-1.85310371]
#  [ 7.11391451]
#  [ 0.020582  ]
#  [-1.59125419]
#  [-4.06300863]]
# [[ 0.020582  ]
#  [-1.59125419]
#  [-4.06300863]
#  [ 6.80983686]
#  [11.60823745]
#  [ 0.76820319]]
# [[ 5.77086128]
#  [-1.94953974]
#  [ 6.71355854]
#  [ 0.75535582]
#  [-0.28657757]
#  [-3.92832507]]
# [[ 0.75535582]
#  [-0.28657757]
#  [-3.92832507]
#  [ 7.27850054]
#  [14.6581293 ]
#  [ 1.71968282]]
# [[ 5.87885052]
#  [-1.89964495]
#  [ 6.32823228]
#  [ 1.34730403]
#  [ 1.33196748]
#  [-3.80712565]]
# [[ 1.34730403]
#  [ 1.33196748]
#  [-3.80712565]
#  [ 3.88817678]
#  [17.55249405]
#  [ 0.0269348 ]]
# [[ 6.02176037]
#  [-1.67404123]
#  [ 5.93860318]
#  [ 1.36730811]
#  [ 3.24443526]
#  [-4.10555089]]
# [[ 1.36730811]
#  [ 3.24443526]
#  [-4.10555089]
#  [-4.73300824]
#  [21.38711087]
#  [-7.14705554]]
# [[ 6.10383893]
#  [-1.22380473]
#  [ 5.47187223]
#  [-0.22194328]
#  [ 6.07971085]
#  [-5.38637818]]
# [[ -0.22194328]
#  [  6.07971085]
#  [ -5.38637818]
#  [-34.14313064]
#  [ 39.85892772]
#  [-16.64171529]]
# [[ 5.81763392]
#  [-0.39702186]
#  [ 4.99226351]
#  [-4.4035401 ]
#  [ 8.42673919]
#  [-1.41721828]]
# [[ -4.4035401 ]
#  [  8.42673919]
#  [ -1.41721828]
#  [ 12.85033596]
#  [-41.25174036]
#  [ 96.15354465]]
# [[ 5.50394081]
#  [ 0.2397406 ]
#  [ 5.14213986]
#  [-1.75569169]
#  [ 4.68258381]
#  [ 3.0759524 ]]
# [[ -1.75569169]
#  [  4.68258381]
#  [  3.0759524 ]
#  [ 20.90676749]
#  [-22.08587137]
#  [ 16.15905228]]
# [[ 5.41602595]
#  [ 0.61513721]
#  [ 5.50597081]
#  [-0.13834085]
#  [ 2.94158859]
#  [ 4.01732286]]
# [[ -0.13834085]
#  [  2.94158859]
#  [  4.01732286]
#  [ 12.84642559]
#  [-15.22739522]
#  [  5.30189478]]
# [[5.45984305]
#  [0.83194388]
#  [5.92766727]
#  [0.96226636]
#  [1.37171648]
#  [4.36680149]]
# [[  0.96226636]
#  [  1.37171648]
#  [  4.36680149]
#  [  9.68564439]
#  [-16.63327594]
#  [  2.31827133]]
# [[ 5.60358661]
#  [ 0.88127344]
#  [ 6.37566939]
#  [ 1.92836612]
#  [-0.44120918]
#  [ 4.60724506]]
# [[  1.92836612]
#  [ -0.44120918]
#  [  4.60724506]
#  [ 10.61059343]
#  [-20.03412366]
#  [  3.1540244 ]]
# [[ 5.86235226]
#  [ 0.72512339]
#  [ 6.8566704 ]
#  [ 3.47278758]
#  [-2.86224782]
#  [ 5.01479588]]
# [[  3.47278758]
#  [ -2.86224782]
#  [  5.01479588]
#  [ 23.89594306]
#  [-30.87293061]
#  [  3.2974161 ]]
# [[ 6.38722294]
#  [ 0.24930221]
#  [ 7.30872473]
#  [ 6.942853  ]
#  [-5.87444725]
#  [ 2.03932862]]
# [[  6.942853  ]
#  [ -5.87444725]
#  [  2.03932862]
#  [ 16.61197991]
#  [  6.06615631]
#  [-85.33147937]]
# [[ 7.00619067]
#  [-0.12821206]
#  [ 7.20722404]
#  [ 4.78705664]
#  [-1.11336378]
#  [-3.05621188]]
# [[  4.78705664]
#  [ -1.11336378]
#  [ -3.05621188]
#  [-18.74313017]
#  [ 38.40467703]
#  [-14.14967923]]
# [[ 7.40015448]
#  [-0.07608911]
#  [ 6.85411048]
#  [ 3.1157967 ]
#  [ 1.89535442]
#  [-3.86479886]]
# [[  3.1157967 ]
#  [  1.89535442]
#  [ -3.86479886]
#  [-17.66785365]
#  [ 23.07763652]
#  [ -5.740025  ]]
# [[ 7.60933361]
#  [ 0.20626759]
#  [ 6.44379227]
#  [ 0.94513282]
#  [ 3.51994166]
#  [-4.23542868]]
# [[  0.94513282]
#  [  3.51994166]
#  [ -4.23542868]
#  [-25.1520908 ]
#  [  8.95042142]
#  [  0.79286803]]
# [[ 7.5797393 ]
#  [ 0.5851482 ]
#  [ 6.04814167]
#  [-1.48797876]
#  [ 3.96847606]
#  [-3.45932387]]
# [[ -1.48797876]
#  [  3.96847606]
#  [ -3.45932387]
#  [-22.30785409]
#  [  3.63471458]
#  [ 14.40876335]]
# [[ 7.32916616]
#  [ 1.00747606]
#  [ 5.80646107]
#  [-3.31551345]
#  [ 4.41312235]
#  [-1.00199937]]
# [[-3.31551345]
#  [ 4.41312235]
#  [-1.00199937]
#  [-9.85613973]
#  [-0.05155527]
#  [35.36238784]]
# [[ 6.99145472]
#  [ 1.40059231]
#  [ 5.86450038]
#  [-3.21287712]
#  [ 3.15303454]
#  [ 1.85677949]]
# [[ -3.21287712]
#  [  3.15303454]
#  [  1.85677949]
#  [  4.37081793]
#  [-19.28509789]
#  [ 16.32734518]]
# [[ 6.68323388]
#  [ 1.61560557]
#  [ 6.10406979]
#  [-3.03160769]
#  [ 1.11283157]
#  [ 2.7199844 ]]
# [[ -3.03160769]
#  [  1.11283157]
#  [  2.7199844 ]
#  [ -0.40468943]
#  [-21.48858323]
#  [  3.55246318]]
# [[ 6.3761164 ]
#  [ 1.61492273]
#  [ 6.38678357]
#  [-3.09750473]
#  [-1.16213784]
#  [ 2.89630997]]
# [[ -3.09750473]
#  [ -1.16213784]
#  [  2.89630997]
#  [  0.36300862]
#  [-23.62598212]
#  [  1.27261518]]
# [[ 6.07997283]
#  [ 1.38098522]
#  [ 6.68904668]
#  [-2.6631381 ]
#  [-3.50479091]
#  [ 3.24008191]]
# [[ -2.6631381 ]
#  [ -3.50479091]
#  [  3.24008191]
#  [ 10.12316293]
#  [-22.82603693]
#  [  6.74142978]]
# [[ 5.89677062]
#  [ 0.91956006]
#  [ 7.055884  ]
#  [-0.62503422]
#  [-5.68518169]
#  [ 4.05580471]]
# [[ -0.62503422]
#  [ -5.68518169]
#  [  4.05580471]
#  [ 32.43182465]
#  [-20.02638514]
#  [  4.35674805]]
# [[ 6.02524916]
#  [ 0.25345421]
#  [ 7.41434094]
#  [ 3.32651747]
#  [-7.6628149 ]
#  [ 2.05106451]]
# [[  3.32651747]
#  [ -7.6628149 ]
#  [  2.05106451]
#  [ 39.36271612]
#  [-22.0742577 ]
#  [-57.94073708]]
# [[ 6.39603639]
#  [-0.46576899]
#  [ 7.22447254]
#  [ 3.1838489 ]
#  [-5.79348137]
#  [-5.36497912]]
# [[  3.1838489 ]
#  [ -5.79348137]
#  [ -5.36497912]
#  [-23.45875589]
#  [ 47.0754816 ]
#  [-40.32964502]]
# [[ 6.6243002 ]
#  [-0.82178015]
#  [ 6.56870077]
#  [ 1.56382881]
#  [-1.45316909]
#  [-7.22760621]]
# [[  1.56382881]
#  [ -1.45316909]
#  [ -7.22760621]
#  [-12.98782993]
#  [ 40.05904495]
#  [ -9.45793168]]
# [[ 6.6979661 ]
#  [-0.77362674]
#  [ 5.79541325]
#  [-0.40472785]
#  [ 2.29768181]
#  [-8.22440181]]
# [[ -0.40472785]
#  [  2.29768181]
#  [ -8.22440181]
#  [-31.20552446]
#  [ 32.16041795]
#  [ -8.28272027]]
# [[ 6.47574295]
#  [-0.43614602]
#  [ 4.99981636]
#  [-4.00507498]
#  [ 4.05309383]
#  [-6.98537859]]
# [[ -4.00507498]
#  [  4.05309383]
#  [ -6.98537859]
#  [-29.71995121]
#  [  7.5845838 ]
#  [ 35.48140184]]
# [[ 5.99384488]
#  [-0.0177409 ]
#  [ 4.54058382]
#  [-4.918181  ]
#  [ 3.89219141]
#  [-2.11259034]]
# [[ -4.918181  ]
#  [  3.89219141]
#  [ -2.11259034]
#  [ 14.73393276]
#  [-19.34096316]
#  [ 43.9611659 ]]
# [[ 5.58611086]
#  [ 0.26393148]
#  [ 4.46742092]
#  [-3.25892374]
#  [ 1.78297798]
#  [ 0.04306687]]
# [[ -3.25892374]
#  [  1.78297798]
#  [  0.04306687]
#  [ 13.45855089]
#  [-17.11579976]
#  [  7.62819548]]
# [[ 5.31845226]
#  [ 0.37005653]
#  [ 4.49492569]
#  [-2.16218077]
#  [ 0.45901159]
#  [ 0.39791309]]
# [[ -2.16218077]
#  [  0.45901159]
#  [  0.39791309]
#  [  9.45556882]
#  [-10.03977103]
#  [  1.19226998]]
# [[ 5.14823596]
#  [ 0.37375033]
#  [ 4.53814738]
#  [-1.24815908]
#  [-0.31344484]
#  [ 0.44946058]]
# [[-1.24815908]
#  [-0.31344484]
#  [ 0.44946058]
#  [ 9.10711184]
#  [-5.74027371]
#  [ 0.18320653]]
# [[ 5.06964078]
#  [ 0.3183315 ]
#  [ 4.58404432]
#  [-0.31664346]
#  [-0.75891059]
#  [ 0.47059311]]
# [[-0.31664346]
#  [-0.75891059]
#  [ 0.47059311]
#  [ 9.5396554 ]
#  [-3.57355785]
#  [ 0.31503802]]
# [[ 5.08643605]
#  [ 0.22491887]
#  [ 4.63338246]
#  [ 0.66110399]
#  [-1.11834053]
#  [ 0.52575678]]
# [[ 0.66110399]
#  [-1.11834053]
#  [ 0.52575678]
#  [10.05597982]
#  [-4.11261256]
#  [ 0.89181788]]
# [[ 5.20450807]
#  [ 0.08755212]
#  [ 4.69284122]
#  [ 1.72558358]
#  [-1.69750729]
#  [ 0.70138947]]
# [[ 1.72558358]
#  [-1.69750729]
#  [ 0.70138947]
#  [11.57050295]
#  [-8.22493943]
#  [ 3.16322084]]
# [[ 5.44163016]
#  [-0.13815535]
#  [ 4.79029491]
#  [ 3.1139715 ]
#  [-3.02721839]
#  [ 1.45051061]]
# [[  3.1139715 ]
#  [ -3.02721839]
#  [  1.45051061]
#  [ 17.40625   ]
#  [-20.85685947]
#  [ 15.23853612]]
# [[ 5.85052709]
#  [-0.58913189]
#  [ 5.08796731]
#  [ 4.45083442]
#  [-5.8335352 ]
#  [ 5.5057548 ]]
# [[  4.45083442]
#  [ -5.8335352 ]
#  [  5.5057548 ]
#  [-12.87738209]
#  [-12.89915994]
#  [ 62.1086946 ]]
# [[ 6.13104721]
#  [-1.03773875]
#  [ 5.74065791]
#  [ 1.05399738]
#  [-2.34502374]
#  [ 6.34872114]]
# [[  1.05399738]
#  [ -2.34502374]
#  [  6.34872114]
#  [-17.71695667]
#  [ 35.28306585]
#  [-11.78610814]]
# [[ 6.17873783]
#  [-1.1146169 ]
#  [ 6.32647597]
#  [ 0.11544338]
#  [ 0.64704347]
#  [ 5.46430563]]
# [[ 0.11544338]
#  [ 0.64704347]
#  [ 5.46430563]
#  [-4.98151705]
#  [26.44447157]
#  [-6.49377175]]
# [[ 6.16517886]
#  [-0.92209315]
#  [ 6.8376448 ]
#  [-0.42693526]
#  [ 3.17083478]
#  [ 4.6712524 ]]
# [[ -0.42693526]
#  [  3.17083478]
#  [  4.6712524 ]
#  [ -7.38982452]
#  [ 24.49303688]
#  [-11.81185186]]
# [[ 6.07486237]
#  [-0.48425454]
#  [ 7.21225946]
#  [-1.39841862]
#  [ 5.50251044]
#  [ 2.35970458]]
# [[ -1.39841862]
#  [  5.50251044]
#  [  2.35970458]
#  [ -8.70296642]
#  [ 19.27362424]
#  [-38.90380373]]
# [[ 5.94713615]
#  [ 0.10666047]
#  [ 7.22358988]
#  [-0.66364888]
#  [ 5.86951754]
#  [-2.03725877]]
# [[ -0.66364888]
#  [  5.86951754]
#  [ -2.03725877]
#  [ 23.19153343]
#  [ -9.06028103]
#  [-34.49411974]]
# [[ 6.01714181]
#  [ 0.62350566]
#  [ 6.91080156]
#  [ 2.09465702]
#  [ 4.21003232]
#  [-3.66228971]]
# [[  2.09465702]
#  [  4.21003232]
#  [ -3.66228971]
#  [ 25.91946526]
#  [-25.3699154 ]
#  [ -0.12351127]]
# [[ 6.32966111]
#  [ 0.89692059]
#  [ 6.56869917]
#  [ 3.93838346]
#  [ 1.12518498]
#  [-3.01584999]]
# [[  3.93838346]
#  [  1.12518498]
#  [ -3.01584999]
#  [ 12.79918242]
#  [-34.52140054]
#  [ 10.1235595 ]]
# [[ 6.78465706]
#  [ 0.82620713]
#  [ 6.33910288]
#  [ 5.12657027]
#  [-2.60538877]
#  [-1.18523805]]
# [[  5.12657027]
#  [ -2.60538877]
#  [ -1.18523805]
#  [ 10.5343637 ]
#  [-38.01616741]
#  [ 33.28349934]]
# [[ 7.26562797]
#  [ 0.48431796]
#  [ 6.41444762]
#  [ 3.96126412]
#  [-3.35224963]
#  [ 2.28436724]]
# [[  3.96126412]
#  [ -3.35224963]
#  [  2.28436724]
#  [-27.71512109]
#  [ 19.73519255]
#  [ 14.15159386]]
# [[ 7.54377019]
#  [ 0.23561995]
#  [ 6.67111473]
#  [ 1.81011419]
#  [-1.80205881]
#  [ 2.59722124]]
# [[  1.81011419]
#  [ -1.80205881]
#  [  2.59722124]
#  [-16.11088801]
#  [  9.97952345]
#  [ -1.2016212 ]]
# [[ 7.6523949 ]
#  [ 0.09430551]
#  [ 6.92360332]
#  [ 0.42684043]
#  [-1.10900177]
#  [ 2.44864423]]
# [[  0.42684043]
#  [ -1.10900177]
#  [  2.44864423]
#  [-12.33785218]
#  [  5.03771364]
#  [ -1.48039628]]
# [[ 7.63588708e+00]
#  [ 7.49957812e-03]
#  [ 7.16156968e+00]
#  [-7.36044579e-01]
#  [-6.22051969e-01]
#  [ 2.31571713e+00]]
# [[ -0.73604458]
#  [ -0.62205197]
#  [  2.31571713]
#  [-11.09348217]
#  [  5.36996786]
#  [ -1.18962845]]
# [[ 7.50774071]
#  [-0.02265822]
#  [ 7.3871981 ]
#  [-1.82347944]
#  [ 0.0848401 ]
#  [ 2.19034536]]
# [[ -1.82347944]
#  [  0.0848401 ]
#  [  2.19034536]
#  [-10.88289753]
#  [  9.33989289]
#  [ -1.57631481]]
# [[ 7.26851165]
#  [ 0.0438185 ]
#  [ 7.59391434]
#  [-3.00804262]
#  [ 1.38187967]
#  [ 1.8613524 ]]
# [[ -3.00804262]
#  [  1.38187967]
#  [  1.8613524 ]
#  [-13.67569395]
#  [ 17.55853919]
#  [ -6.49089615]]
# [[ 6.88627929]
#  [ 0.29333527]
#  [ 7.71650118]
#  [-4.72520326]
#  [ 3.8323633 ]
#  [ 0.01081768]]
# [[-4.72520326e+00]
#  [ 3.83236330e+00]
#  [ 1.08176825e-02]
#  [-1.87932883e+01]
#  [ 3.01023165e+01]
#  [-3.94330010e+01]]
# [[ 6.41229831]
#  [ 0.73513142]
#  [ 7.46675673]
#  [-4.04339694]
#  [ 4.14468797]
#  [-4.65401252]]
# [[ -4.04339694]
#  [  4.14468797]
#  [ -4.65401252]
#  [ 28.73610518]
#  [-24.52694273]
#  [-22.83439256]]
# [[ 6.13196494]
#  [ 1.01999271]
#  [ 6.96231868]
#  [-1.82093823]
#  [ 1.59523474]
#  [-4.9909868 ]]
# [[ -1.82093823]
#  [  1.59523474]
#  [ -4.9909868 ]
#  [ 14.16677784]
#  [-23.25862749]
#  [  4.60461754]]
# [[ 6.00566546]
#  [ 1.06968269]
#  [ 6.48620794]
#  [-0.81151698]
#  [-0.54583491]
#  [-4.54269308]]
# [[ -0.81151698]
#  [ -0.54583491]
#  [ -4.54269308]
#  [  7.84832422]
#  [-20.15602961]
#  [  4.03372217]]
# [[ 5.96442373]
#  [ 0.91582016]
#  [ 6.05365253]
#  [ 0.01925596]
#  [-2.52684903]
#  [-4.06755234]]
# [[ 1.92559629e-02]
#  [-2.52684903e+00]
#  [-4.06755234e+00]
#  [ 9.80312629e+00]
#  [-1.98893432e+01]
#  [ 6.49244288e+00]]
# [[ 6.02653882]
#  [ 0.55795052]
#  [ 5.69372628]
#  [ 1.36836839]
#  [-4.75628269]
#  [-2.9026678 ]]
# [[  1.36836839]
#  [ -4.75628269]
#  [ -2.9026678 ]
#  [ 18.67699068]
#  [-27.37960328]
#  [ 20.28675585]]
# [[ 6.2767013 ]
#  [-0.09916548]
#  [ 5.58692757]
#  [ 3.01799981]
#  [-8.22556216]
#  [ 1.91527168]]
# [[  3.01799981]
#  [ -8.22556216]
#  [  1.91527168]
#  [-12.15553737]
#  [-17.80767653]
#  [ 74.23209667]]
# [[ 6.38255371]
#  [-0.79546465]
#  [ 5.91165284]
#  [-1.08212826]
#  [-4.90826535]
#  [ 3.2138624 ]]
# [[ -1.08212826]
#  [ -4.90826535]
#  [  3.2138624 ]
#  [-24.27390998]
#  [ 30.83043722]
#  [-12.28642059]]
# [[ 6.19055013]
#  [-1.15198085]
#  [ 6.17730111]
#  [-2.46649941]
#  [-2.38278114]
#  [ 2.18130007]]
# [[-2.46649941]
#  [-2.38278114]
#  [ 2.18130007]
#  [-6.89454025]
#  [21.64025591]
#  [-7.74329187]]
# [[ 5.92064858]
#  [-1.28718024]
#  [ 6.36138906]
#  [-2.84734011]
#  [-0.36958464]
#  [ 1.52246058]]
# [[-2.84734011]
#  [-0.36958464]
#  [ 1.52246058]
#  [-1.84349663]
#  [18.80122099]
#  [-6.52636356]]
# [[ 5.62885381]
#  [-1.23448262]
#  [ 6.47462612]
#  [-2.97045003]
#  [ 1.37420195]
#  [ 0.649805  ]]
# [[ -2.97045003]
#  [  1.37420195]
#  [  0.649805  ]
#  [ -0.74669405]
#  [ 15.80580503]
#  [-12.12618965]]
# [[ 5.33448935]
#  [-1.02862128]
#  [ 6.4623239 ]
#  [-2.80239852]
#  [ 2.59911331]
#  [-1.03292097]]
# [[ -2.80239852]
#  [  2.59911331]
#  [ -1.03292097]
#  [  6.23949034]
#  [  6.91141742]
#  [-20.28722775]]
# [[ 5.10687797]
#  [-0.75490204]
#  [ 6.26616543]
#  [-1.58920416]
#  [ 2.72689217]
#  [-2.75224504]]
# [[ -1.58920416]
#  [  2.72689217]
#  [ -2.75224504]
#  [ 16.37291255]
#  [ -2.25225616]
#  [-12.03271087]]
# [[ 5.03585349]
#  [-0.49970117]
#  [ 5.94835023]
#  [ 0.20556685]
#  [ 2.30088031]
#  [-3.44352198]]
# [[ 0.20556685]
#  [ 2.30088031]
#  [-3.44352198]
#  [18.68039497]
#  [-6.93679672]
#  [-2.26400925]]
# [[ 5.14770463]
#  [-0.31741198]
#  [ 5.60492114]
#  [ 2.00410073]
#  [ 1.20879264]
#  [-3.3235041 ]]
# [[  2.00410073]
#  [  1.20879264]
#  [ -3.3235041 ]
#  [ 17.0281042 ]
#  [-15.30099108]
#  [  3.93454519]]
# [[ 5.43270309]
#  [-0.29079016]
#  [ 5.30173952]
#  [ 3.71994964]
#  [-0.87697095]
#  [-2.58431706]]
# [[  3.71994964]
#  [ -0.87697095]
#  [ -2.58431706]
#  [ 18.45394286]
#  [-27.42413706]
#  [ 13.29550176]]
# [[ 5.89398136]
#  [-0.52737769]
#  [ 5.16293717]
#  [ 5.05387482]
#  [-3.38403818]
#  [ 0.26459047]]
# [[ 5.05387482]
#  [-3.38403818]
#  [ 0.26459047]
#  [-5.61580311]
#  [-1.71083493]
#  [37.88214146]]
# [[ 6.32504999]
#  [-0.7836108 ]
#  [ 5.30041416]
#  [ 3.44361128]
#  [-1.34635381]
#  [ 1.94506573]]
# [[  3.44361128]
#  [ -1.34635381]
#  [  1.94506573]
#  [-13.14159591]
#  [ 22.49732737]
#  [  3.42752499]]
# [[ 6.61433226]
#  [-0.81724827]
#  [ 5.50255285]
#  [ 2.41142592]
#  [ 0.56951571]
#  [ 2.03656264]]
# [[ 2.41142592]
#  [ 0.56951571]
#  [ 2.03656264]
#  [-9.06466325]
#  [16.36779014]
#  [-0.23580084]]
# [[ 6.80769344]
#  [-0.6854905 ]
#  [ 5.70404736]
#  [ 1.41634945]
#  [ 2.00510516]
#  [ 1.98465186]]
# [[  1.41634945]
#  [  2.00510516]
#  [  1.98465186]
#  [-11.47383934]
#  [ 12.71679571]
#  [ -0.74440481]]
# [[ 6.88414215]
#  [-0.42357408]
#  [ 5.89856251]
#  [ 0.02186254]
#  [ 3.24140299]
#  [ 1.90923786]]
# [[  0.02186254]
#  [  3.24140299]
#  [  1.90923786]
#  [-17.02302147]
#  [ 13.20826421]
#  [ -0.52301053]]
# [[ 6.78376428]
#  [-0.0190205 ]
#  [ 6.09217   ]
#  [-2.25427576]
#  [ 5.03616347]
#  [ 2.12495811]]
# [[ -2.25427576]
#  [  5.03616347]
#  [  2.12495811]
#  [-30.45412184]
#  [ 24.38648697]
#  [  8.87428992]]
# [[ 6.46410348]
#  [ 0.50299752]
#  [ 6.43523858]
#  [-3.30638072]
#  [ 4.34383227]
#  [ 4.90887819]]
# [[ -3.30638072]
#  [  4.34383227]
#  [  4.90887819]
#  [ 22.10011565]
#  [-45.46499844]
#  [ 25.91937086]]
# [[ 6.24311596]
#  [ 0.74566324]
#  [ 6.99803252]
#  [-1.18623285]
#  [ 0.90824129]
#  [ 5.93523101]]
# [[ -1.18623285]
#  [  0.90824129]
#  [  5.93523101]
#  [ 19.01889293]
#  [-22.04307382]
#  [  0.81132621]]
# [[ 6.2116382 ]
#  [ 0.76251252]
#  [ 7.5752785 ]
#  [ 0.45304555]
#  [-0.28923329]
#  [ 5.46579618]]
# [[ 0.45304555]
#  [-0.28923329]
#  [ 5.46579618]
#  [13.09861449]
#  [-4.53414949]
#  [-8.45561838]]
# [[ 6.31075463]
#  [ 0.72010206]
#  [ 8.07566823]
#  [ 1.42348694]
#  [-0.51315978]
#  [ 4.52516535]]
# [[ 1.42348694]
#  [-0.51315978]
#  [ 4.52516535]
#  [ 6.77119134]
#  [-1.66614558]
#  [-9.68684252]]
# [[ 6.47973321]
#  [ 0.65742021]
#  [ 8.47903461]
#  [ 1.88926729]
#  [-0.77341031]
#  [ 3.52964379]]
# [[  1.88926729]
#  [ -0.77341031]
#  [  3.52964379]
#  [  2.76979175]
#  [ -3.66653904]
#  [-10.5301793 ]]
# [[ 6.67619733]
#  [ 0.55938184]
#  [ 8.77555385]
#  [ 1.96939272]
#  [-1.19355441]
#  [ 2.36335296]]
# [[  1.96939272]
#  [ -1.19355441]
#  [  2.36335296]
#  [ -1.49141682]
#  [ -4.03215942]
#  [-12.79298665]]
# [[ 6.85552961]
#  [ 0.42618242]
#  [ 8.94748044]
#  [ 1.5207804 ]
#  [-1.39614331]
#  [ 1.09847182]]
# [[  1.5207804 ]
#  [ -1.39614331]
#  [  1.09847182]
#  [ -7.42352585]
#  [  0.57766709]
#  [-11.38187416]]
# [[ 6.96423097]
#  [ 0.29709966]
#  [ 9.00893143]
#  [ 0.61185402]
#  [-1.1299053 ]
#  [ 0.20798488]]
# [[ 0.61185402]
#  [-1.1299053 ]
#  [ 0.20798488]
#  [-9.98011457]
#  [ 4.02400572]
#  [-6.64168488]]
# [[ 6.97516009]
#  [ 0.20614912]
#  [ 9.00105051]
#  [-0.39429268]
#  [-0.67235005]
#  [-0.33482301]]
# [[ -0.39429268]
#  [ -0.67235005]
#  [ -0.33482301]
#  [-10.04286303]
#  [  5.04988911]
#  [ -4.77290633]]
# [[ 6.88570365]
#  [ 0.1657794 ]
#  [ 8.94282021]
#  [-1.39173211]
#  [-0.12134392]
#  [-0.85312397]]
# [[-1.39173211]
#  [-0.12134392]
#  [-0.85312397]
#  [-9.8846963 ]
#  [ 5.91683274]
#  [-6.16979773]]
# [[ 6.69878597]
#  [ 0.18236413]
#  [ 8.81928404]
#  [-2.30956415]
#  [ 0.41923105]
#  [-1.70645645]]
# [[ -2.30956415]
#  [  0.41923105]
#  [ -1.70645645]
#  [ -7.71499954]
#  [  3.93112234]
#  [-11.514087  ]]

# %%
x = [0,1,2,3]
for i in range(1, 3+1, 1): 
    print(x[i])
# Out:
# 1
# 2
# 3
